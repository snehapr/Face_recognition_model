# %%
#Real Time Face Recognition project

# %%
from imutils import paths
import face_recognition
import argparse
import pickle
import cv2
import os

# %%
ap=argparse.ArgumentParser()
ap.add_argument("-i", "--dataset", required=True, help="path to input directory of faces + images")
ap.add_argument("-e", "--encodings", required=True, help="path to serialized db of facial encodings")
ap.add_argument("-d", "--detection-method", type=str, default="cnn", help="face detection model to use: either `hog` or `cnn`")
args= vars(ap.parse_args)

# %%
# grab the paths to the input images in our dataset
print("Quantifying faces...")
imagePaths = list(paths.list_images("dataset"))
# initialize the list of known encodings and known names
knownEncodings = []
knownNames = []
# Out:
# Quantifying faces...

# %%
print(imagePaths)
# Out:
# ['dataset\\alan_grant\\159794291-288-k225882.jpg', 'dataset\\alan_grant\\2213_00121_tall.jpg', 'dataset\\alan_grant\\2213_00392_head.jpg', 'dataset\\alan_grant\\2213_00392_mobile.jpg', 'dataset\\alan_grant\\2213_00543_quote.jpg', 'dataset\\alan_grant\\41I4Mqz9gSL._SR6002C315_PIWhiteStrip2CBottomLeft2C02C35_SCLZZZZZZZ_.jpg', 'dataset\\alan_grant\\7b4cf8f997ec1f111d271da9f1172859.jpg', 'dataset\\alan_grant\\7c33e1989c7c15c1880bc4fa7cd4c054.jpg', 'dataset\\alan_grant\\Alan-Grant.png', 'dataset\\alan_grant\\alan-grants-hat.jpg', 'dataset\\alan_grant\\f456708ea673a16ea4c4736fec2535d689f65c6c.png', 'dataset\\alan_grant\\GrantandThePhone.png', 'dataset\\alan_grant\\Grantjp3still.jpg', 'dataset\\alan_grant\\GrantProfile.png', 'dataset\\alan_grant\\hqdefault.jpg', 'dataset\\alan_grant\\I-Love-Sam-Neill-With-My-Whole-Heart.jpeg', 'dataset\\alan_grant\\image.jpeg', 'dataset\\alan_grant\\image1.jpeg', 'dataset\\alan_grant\\image10.jpeg', 'dataset\\alan_grant\\image11.jpeg', 'dataset\\alan_grant\\image13.jpeg', 'dataset\\alan_grant\\image14.jpeg', 'dataset\\alan_grant\\image15.jpeg', 'dataset\\alan_grant\\image16.jpeg', 'dataset\\alan_grant\\image17.jpeg', 'dataset\\alan_grant\\image2.jpeg', 'dataset\\alan_grant\\image3.jpeg', 'dataset\\alan_grant\\image5.jpeg', 'dataset\\alan_grant\\image6.jpeg', 'dataset\\alan_grant\\image7.jpeg', 'dataset\\alan_grant\\images.jpg', 'dataset\\alan_grant\\images100.jpg', 'dataset\\alan_grant\\images101.jpg', 'dataset\\alan_grant\\images102.jpg', 'dataset\\alan_grant\\images103.jpg', 'dataset\\alan_grant\\images105.jpg', 'dataset\\alan_grant\\images106.jpg', 'dataset\\alan_grant\\images17.jpg', 'dataset\\alan_grant\\images21.jpg', 'dataset\\alan_grant\\images26.jpg', 'dataset\\alan_grant\\images30.jpg', 'dataset\\alan_grant\\images32.jpg', 'dataset\\alan_grant\\images33.jpg', 'dataset\\alan_grant\\images34.jpg', 'dataset\\alan_grant\\images38.jpg', 'dataset\\alan_grant\\images39.jpg', 'dataset\\alan_grant\\images42.jpg', 'dataset\\alan_grant\\images49.jpg', 'dataset\\alan_grant\\images50.jpg', 'dataset\\alan_grant\\images52.jpg', 'dataset\\alan_grant\\images60.jpg', 'dataset\\alan_grant\\images63.jpg', 'dataset\\alan_grant\\images65.jpg', 'dataset\\alan_grant\\images68.jpg', 'dataset\\alan_grant\\images75.jpg', 'dataset\\alan_grant\\images76.jpg', 'dataset\\alan_grant\\images80.jpg', 'dataset\\alan_grant\\images82.jpg', 'dataset\\alan_grant\\images84.jpg', 'dataset\\alan_grant\\images94.jpg', 'dataset\\alan_grant\\images95.jpg', 'dataset\\alan_grant\\Jurassic-Park-Sam-Neill-696x442.jpg', 'dataset\\alan_grant\\Jurassic-Park-Sam-Neill-as-Alan-Grant-on-helicopter.jpg', 'dataset\\alan_grant\\jurpkag-main1.jpg', 'dataset\\alan_grant\\maxresdefault0.jpg', 'dataset\\alan_grant\\p-jurassic-park-sam-neill.jpg', 'dataset\\alan_grant\\sam-neill-dr-alan-grant-jurassic-park.jpg', 'dataset\\alan_grant\\sam-neill-jurassic-park-alan-grant-dennis-nedry-youtube-png-alan-grant-png-820_1009.jpg', 'dataset\\alan_grant\\sam-neill-jurassic-park-iii-2001-BPH95X.jpg', 'dataset\\ellie_sattler\\-Ellie-Sattler-jurassic-park-38766750-200-200.jpg', 'dataset\\ellie_sattler\\2213_00277_mob.jpg', 'dataset\\ellie_sattler\\2213_01049_quote.jpg', 'dataset\\ellie_sattler\\34jdpop.png', 'dataset\\ellie_sattler\\382e0be1ee94df2af219a3d12b0473b7.jpg', 'dataset\\ellie_sattler\\715cf7395e71d6c531fe74eb0d43b0c3161fd983.jpg', 'dataset\\ellie_sattler\\8661496232_2df568ba28_n.jpg', 'dataset\\ellie_sattler\\afce1147f160dd6f9bbd85a1f66bdd89ea1131e6.jpg', 'dataset\\ellie_sattler\\Dern-Header-Jurassic-Park.jpg', 'dataset\\ellie_sattler\\dr-ellie-sattler-1680x1120.jpg', 'dataset\\ellie_sattler\\Dr._Ellie_Sattler_park.jpg', 'dataset\\ellie_sattler\\DrEllie.jpg', 'dataset\\ellie_sattler\\ellie-sattler.jpg', 'dataset\\ellie_sattler\\Elliejp3still.jpg', 'dataset\\ellie_sattler\\elliesattler02.jpg', 'dataset\\ellie_sattler\\Ellie_Dgeler.png', 'dataset\\ellie_sattler\\Extraptorshedbig.jpg', 'dataset\\ellie_sattler\\f793d3f9abed7467c7a24efd7855757580ad2958.jpg', ' ...

# %%
# loop over the image paths
for (i, imagePath) in enumerate(imagePaths):
    # extract the person name from the image path
    print("processing image {}/{}".format(i + 1,len(imagePaths)))
    name = imagePath.split(os.path.sep)[-2]
    #print(name)
    # load the input image and convert it from BGR (OpenCV ordering)
    # to dlib ordering (RGB)
    image = cv2.imread(imagePath)
    rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    # detect the (x, y)-coordinates of the bounding boxes
    # corresponding to each face in the input image
    boxes = face_recognition.face_locations(rgb,model="detection_method")
    # compute the facial embedding for the face
    encodings = face_recognition.face_encodings(rgb, boxes)
    # loop over the encodings
    for encoding in encodings:
        # add each encoding + name to our set of known names and
        # encodings
        knownEncodings.append(encoding)
        knownNames.append(name)
# Out:
# processing image 1/222
# processing image 2/222
# processing image 3/222
# processing image 4/222
# processing image 5/222
# processing image 6/222
# processing image 7/222
# processing image 8/222
# processing image 9/222
# processing image 10/222
# processing image 11/222
# processing image 12/222
# processing image 13/222
# processing image 14/222
# processing image 15/222
# processing image 16/222
# processing image 17/222
# processing image 18/222
# processing image 19/222
# processing image 20/222
# processing image 21/222
# processing image 22/222
# processing image 23/222
# processing image 24/222
# processing image 25/222
# processing image 26/222
# processing image 27/222
# processing image 28/222
# processing image 29/222
# processing image 30/222
# processing image 31/222
# processing image 32/222
# processing image 33/222
# processing image 34/222
# processing image 35/222
# processing image 36/222
# processing image 37/222
# processing image 38/222
# processing image 39/222
# processing image 40/222
# processing image 41/222
# processing image 42/222
# processing image 43/222
# processing image 44/222
# processing image 45/222
# processing image 46/222
# processing image 47/222
# processing image 48/222
# processing image 49/222
# processing image 50/222
# processing image 51/222
# processing image 52/222
# processing image 53/222
# processing image 54/222
# processing image 55/222
# processing image 56/222
# processing image 57/222
# processing image 58/222
# processing image 59/222
# processing image 60/222
# processing image 61/222
# processing image 62/222
# processing image 63/222
# processing image 64/222
# processing image 65/222
# processing image 66/222
# processing image 67/222
# processing image 68/222
# processing image 69/222
# processing image 70/222
# processing image 71/222
# processing image 72/222
# processing image 73/222
# processing image 74/222
# processing image 75/222
# processing image 76/222
# processing image 77/222
# processing image 78/222
# processing image 79/222
# processing image 80/222
# processing image 81/222
# processing image 82/222
# processing image 83/222
# processing image 84/222
# processing image 85/222
# processing image 86/222
# processing image 87/222
# processing image 88/222
# processing image 89/222
# processing image 90/222
# processing image 91/222
# processing image 92/222
# processing image 93/222
# processing image 94/222
# processing image 95/222
# processing image 96/222
# processing image 97/222
# processing image 98/222
# processing image 99/222
# processing image 100/222
# processing image 101/222
# processing image 102/222
# processing image 103/222
# processing image 104/222
# processing image 105/222
# processing image 106/222
# processing image 107/222
# processing image 108/222
# processing image 109/222
# processing image 110/222
# processing image 111/222
# processing image 112/222
# processing image 113/222
# processing image 114/222
# processing image 115/222
# processing image 116/222
# processing image 117/222
# processing image 118/222
# processing image 119/222
# processing image 120/222
# processing image 121/222
# processing image 122/222
# processing image 123/222
# processing image 124/222
# processing image 125/222
# processing image 126/222
# processing image 127/222
# processing image 128/222
# processing image 129/222
# processing image 130/222
# processing image 131/222
# processing image 132/222
# processing image 133/222
# processing image 134/222
# processing image 135/222
# processing image 136/222
# processing image 137/222
# processing image 138/222
# processing image 139/222
# processing image 140/222
# processing image 141/222
# processing image 142/222
# processing image 143/222
# processing image 144/222
# processing image 145/222
# processing image 146/222
# processing image 147/222
# processing image 148/222
# processing image 149/222
# processing image 150/222
# processing image 151/222
# processing image 152/222
# processing image 153/222
# processing image 154/222
# processing image 155/222
# processing image 156/222
# processing image 157/222
# processing image 158/222
# processing image 159/222
# processing image 160/222
# processing image 161/222
# processing image 162/222
# processing image 163/222
# processing image 164/222
# processing image 165/222
# processing image 166/222
# processing image 167/222
# processing image 168/222
# processing image 169/222
# processing image 170/222
# processing image 171/222
# processing image 172/222
# processing image 173/222
# processing image 174/222
# processing image 175/222
# processing image 176/222
# processing image 177/222
# processing image 178/222
# processing image 179/222
# processing image 180/222
# processing image 181/222
# processing image 182/222
# processing image 183/222
# processing image 184/222
# processing image 185/222
# processing image 186/222
# processing image 187/222
# processing image 188/222
# processing image 189/222
# processing image 190/222
# processing image 191/222
# processing image 192/222
# processing image 193/222
# processing image 194/222
# processing image 195/222
# processing image 196/222
# processing image 197/222
# processing image 198/222
# processing image 199/222
# processing image 200/222
# processing image 201/222
# processing image 202/222
# processing image 203/222
# processing image 204/222
# processing image 205/222
# processing image 206/222
# processing image 207/222
# processing image 208/222
# processing image 209/222
# processing image 210/222
# processing image 211/222
# processing image 212/222
# processing image 213/222
# processing image 214/222
# processing image 215/222
# processing image 216/222
# processing image 217/222
# processing image 218/222
# processing image 219/222
# processing image 220/222
# processing image 221/222
# processing image 222/222

# %%
# dump the facial encodings + names to disk
print("serializing encodings...")
data = {"encodings": knownEncodings, "names": knownNames}
f = open("encodings", "wb")
f.write(pickle.dumps(data))
f.close()
# Out:
# serializing encodings...
